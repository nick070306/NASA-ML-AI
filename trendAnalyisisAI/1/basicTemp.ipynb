# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
#boo

# Sample dataset creation with more samples per class
data = {
    'value': [10, 15, 20, 25, 30, 35, 40, 45, 5, 12, 22, 28, 33, 38, 41, 44],
    'label': ['low', 'low', 'ok', 'ok', 'ok', 'high', 'high', 'high', 'low', 'low', 'ok', 'ok', 'high', 'high', 'high', 'high']
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Feature and label separation
X = df[['value']]
y = df['label']

# Check the number of unique classes
num_classes = y.nunique()

if len(X) < num_classes:
    raise ValueError(f"Not enough samples to create a test set with each class present. Total samples: {len(X)}, Classes: {num_classes}")

# Adjusted test size, ensuring it's greater than or equal to the number of classes
test_size = 0.25  # 25% might be fine here

# Stratified train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42, stratify=y)

# Train the model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Evaluate the model
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred, zero_division=0))

# Function to classify a new input
def check_value(input_value):
    # Create a DataFrame with the input_value and proper column name
    input_df = pd.DataFrame([[input_value]], columns=['value'])
    prediction = model.predict(input_df)
    return prediction[0]

# Testing new inputs
new_values = [12, 45, 78, 23, 67, 34, 89, 15, 54, 73, 6, 28, 91, 41, 62, 5, 77, 36, 50, 83, 19, 8, 92, 48, 60, 39, 16, 85, 71, 26]
for value in new_values:
    result = check_value(value)
    print(f'Input: {value}, Classification: {result}')
# Out:
#               precision    recall  f1-score   support
#
#         high       1.00      1.00      1.00         2
#          low       1.00      1.00      1.00         1
#           ok       1.00      1.00      1.00         1
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
# Input: 12, Classification: low
# Input: 45, Classification: high
# Input: 78, Classification: high
# Input: 23, Classification: ok
# Input: 67, Classification: high
# Input: 34, Classification: high
# Input: 89, Classification: high
# Input: 15, Classification: low
# Input: 54, Classification: high
# Input: 73, Classification: high
# Input: 6, Classification: low
# Input: 28, Classification: ok
# Input: 91, Classification: high
# Input: 41, Classification: high
# Input: 62, Classification: high
# Input: 5, Classification: low
# Input: 77, Classification: high
# Input: 36, Classification: high
# Input: 50, Classification: high
# Input: 83, Classification: high
# Input: 19, Classification: ok
# Input: 8, Classification: low
# Input: 92, Classification: high
# Input: 48, Classification: high
# Input: 60, Classification: high
# Input: 39, Classification: high
# Input: 16, Classification: low
# Input: 85, Classification: high
# Input: 71, Classification: high
# Input: 26, Classification: ok
