# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Sample dataset creation with more samples per class
df = pd.read_csv('../datasets/portableWaterDispensingLogsTrain.csv')

# Assuming the columns in the CSV are named 'Temperature' and 'Status'
data = {
    'value': df['Dispensing Rate'].tolist(),
    'label': df['Status'].tolist()
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Feature and label separation
X = df[['value']]
y = df['label']

# Check the number of unique classes
num_classes = y.nunique()

if len(X) < num_classes:
    raise ValueError(f"Not enough samples to create a test set with each class present. Total samples: {len(X)}, Classes: {num_classes}")

# Adjusted test size, ensuring it's greater than or equal to the number of classes
test_size = 0.25  # 25% might be fine here

# Stratified train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42, stratify=y)

# Train the model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Evaluate the model
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred, zero_division=0))





# Function to classify a new input
def ck_value(input_values):
    # Create a DataFrame with the input_values and proper column names
    input_df = pd.DataFrame([input_values], columns=labels)
    prediction = model2.predict(input_df)
    return prediction[0]

# Load test data from the 'datasets' folder
tdf = pd.read_csv('../datasets/waterTempLogsTest.csv')

labels = ['Dispensing Rate']  # You can modify this list as needed
new_values = tdf[labels].values.tolist()  # Extract rows for the selected features
status_values = tdf['Status'].tolist()  # Extract the 'status' column for comparison

# Iterate through the inputs and make predictions
for values, status in zip(new_values, status_values):
    # Dynamically create the Input label-output string
    input_details = ', '.join(f"{label}: {value}" for label, value in zip(labels, values))
    print(f'Input: ({input_details}), Classification: {result}, Real Result: {status}')

# Save the model to the 'models' folder
joblib.dump(model, '../models/potable_water_dispensing_rate.pkl')
# Out:
#               precision    recall  f1-score   support
#
#    ANOMALOUS       1.00      1.00      1.00         3
#       NORMAL       1.00      1.00      1.00       122
#
#     accuracy                           1.00       125
#    macro avg       1.00      1.00      1.00       125
# weighted avg       1.00      1.00      1.00       125
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2168\1068017360.py in <module>
#      56
#      57 labels = ['Dispensing Rate']  # You can modify this list as needed
# ---> 58 new_values = tdf[labels].values.tolist()  # Extract rows for the selected features
#      59 status_values = tdf['Status'].tolist()  # Extract the 'status' column for comparison
#      60
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5854                 if use_interval_msg:
#    5855                     key = list(key)
# -> 5856                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Dispensing Rate'], dtype='object')] are in the [columns]"

# %%
model2 = joblib.load('../models/potable_water_dispensing_rate.pkl')

# %%
def ck_value(input_value):
    # Create a DataFrame with the input_value and proper column name
    input_df = pd.DataFrame([[input_value]], columns=['value'])
    prediction = model2.predict(input_df)
    return prediction[0]

#Test data
tdf = pd.read_csv('../datasets/portableWaterDispensingLogsTest.csv')


labels = ['Dispensing Rate']  # You can modify this list as needed
new_values = tdf[labels].values.tolist()  # Extract rows for the selected features
status_values = tdf['Status'].tolist()  # Extract the 'status' column for comparison

# Iterate through the inputs and make predictions
for values, status in zip(new_values, status_values):
    # Dynamically create the Input label-output string
    input_details = ', '.join(f"{label}: {value}" for label, value in zip(labels, values))
    print(f'Input: ({input_details}), Classification: {result}, Real Result: {status}')
# Out:
# Input: (Dispensing Rate: 2.0), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.02), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.81), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 2.07), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.1), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.12), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.14), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.15), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 3.08), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.11), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.14), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.12), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.35), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 2.08), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.05), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.03), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.0), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.98), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.95), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.93), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.91), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.89), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.87), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.85), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.38), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.84), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.86), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.88), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.9), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.92), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.94), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.97), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.99), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.02), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.04), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.07), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.09), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.11), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.13), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.15), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.89), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.12), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.1), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.08), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.06), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.03), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.01), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.98), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.96), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.94), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.91), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.89), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.87), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.85), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.84), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.84), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.85), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.87), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.89), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.91), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.94), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.96), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.99), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.01), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.04), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.06), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.08), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.11), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.13), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.14), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.15), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.13), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.11), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 3.03), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 2.07), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.04), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.03), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.99), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.97), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.54), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.92), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.9), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.88), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.86), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.84), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.66), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.85), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.85), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.87), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.89), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.91), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.01), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 1.96), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.98), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.01), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.03), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.05), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.08), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.1), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.12), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.56), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.15), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.14), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.12), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.09), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.07), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.05), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.02), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.0), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.97), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.95), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.93), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.9), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.88), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.86), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.85), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.56), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.22), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.05), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 1.86), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.88), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.9), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.93), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.95), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.97), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.0), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.02), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.05), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.07), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.09), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.49), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.75), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.15), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.14), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.12), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.1), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.08), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.05), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.03), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.0), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.98), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.96), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.93), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.91), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.89), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.87), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.85), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.84), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.86), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.88), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.9), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.92), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.94), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.97), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.99), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.02), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.04), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.07), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.09), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.11), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.13), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.15), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.58), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.14), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.13), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.11), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.08), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.06), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.04), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.01), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.99), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.96), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.94), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.91), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.89), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.87), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.85), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.84), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.03), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.84), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.85), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.87), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.89), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.22), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.94), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.96), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.99), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.01), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.03), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.06), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.08), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.1), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.13), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.14), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.15), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.13), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.11), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.09), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.07), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.04), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.02), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.99), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.97), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.92), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.9), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.88), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.86), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.84), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.85), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.87), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.89), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.56), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 1.79), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.95), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.08), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 2.0), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.03), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.05), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.08), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.1), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.12), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.14), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.15), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.17), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 2.12), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.1), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.07), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.56), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 2.02), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.0), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.97), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.95), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.93), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.9), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.88), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.86), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.85), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.11), Classification: ANOMALOUS, Real Result: ANOMALOUS
# Input: (Dispensing Rate: 1.84), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.86), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.88), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.9), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.92), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.95), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.52), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.0), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.02), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.05), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.07), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.09), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.11), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.13), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.15), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.7), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.14), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.12), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.1), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.08), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.06), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.03), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.01), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.98), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.96), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.93), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.91), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.89), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.87), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.85), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.84), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.84), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.86), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.88), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.9), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.92), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.94), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.97), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.99), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.02), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.04), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.06), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.09), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.11), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.13), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.15), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.18), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.2), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.64), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.17), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.16), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.15), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.13), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.11), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.09), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.06), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.04), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.01), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.99), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.96), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.94), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.92), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.89), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.87), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.86), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.84), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.83), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 2.19), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.8), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.81), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.82), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.84), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.85), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.87), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 1.89), Classification: ANOMALOUS, Real Result: NORMAL
# Input: (Dispensing Rate: 0.98), Classification: ANOMALOUS, Real Result: ANOMALOUS
